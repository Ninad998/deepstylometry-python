# %%
import DatabaseQueryUpdate as db

# %%
from sshtunnel import SSHTunnelForwarder
PORT=5432
with SSHTunnelForwarder(('srn01.cs.cityu.edu.hk', 22),
                        ssh_username='stylometry',
                        ssh_password='stylometry',
                        remote_bind_address=('localhost', 5432),
                        local_bind_address=('localhost', 5400)):
    bigDocument = db.getDocBigData(5400)
# Out:
# Execution completed
# Read completed
# Number of rows: 27679
# <type 'list'>
# doc_id          int64
# doc_title      object
# year_of_pub    object
# dtype: object
# Data Frame created: Shape: (27679, 3)

# %%
from sshtunnel import SSHTunnelForwarder
PORT=5432
with SSHTunnelForwarder(('srn02.cs.cityu.edu.hk', 22),
                        ssh_username='stylometry',
                        ssh_password='stylometry',
                        remote_bind_address=('localhost', 5432),
                        local_bind_address=('localhost', 5400)):
    smallDocument = db.getDocSmallData(5400)
# Out:
# Execution completed
# Read completed
# Number of rows: 2386
# <type 'list'>
# doc_id          int64
# doc_title      object
# year_of_pub    object
# dtype: object
# Data Frame created: Shape: (2386, 3)

# %%
print("Data Frame created: Shape: %s" % (str(bigDocument.shape)))
print("Data Frame created: Shape: %s" % (str(smallDocument.shape)))
# Out:
# Data Frame created: Shape: (27679, 3)
# Data Frame created: Shape: (2386, 3)

# %%
df = bigDocument.loc[ bigDocument['doc_title'] == smallDocument.loc[10]['doc_title'] ]

# %%
for index, row in smallDocument.iterrows():
    df = bigDocument.loc[ bigDocument['doc_title'] == row['doc_title'] ]
    doc_id = df['doc_id']
    doc_title = df['doc_id']
    year_of_pub = df['doc_id']
    print('doc_id = %s ' % (doc_id))
    print('doc_title = %s ' % (doc_title))
    print('year_of_pub = %s ' % (year_of_pub))
#     from sshtunnel import SSHTunnelForwarder
#     PORT=5432
#     with SSHTunnelForwarder(('srn02.cs.cityu.edu.hk', 22),
#                             ssh_username='stylometry',
#                             ssh_password='stylometry',
#                             remote_bind_address=('localhost', 5432),
#                             local_bind_address=('localhost', 5400)):
#         smallDocument = db.updateDocSmallData(5400, doc_id, doc_title, year_of_pub)
# Out:
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 20069    21165
# Name: doc_id, dtype: int64
# doc_title = 20069    21165
# Name: doc_id, dtype: int64
# year_of_pub = 20069    21165
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 6826    7251
# Name: doc_id, dtype: int64
# doc_title = 6826    7251
# Name: doc_id, dtype: int64
# year_of_pub = 6826    7251
# Name: doc_id, dtype: int64
# doc_id = 15680    16633
# Name: doc_id, dtype: int64
# doc_title = 15680    16633
# Name: doc_id, dtype: int64
# year_of_pub = 15680    16633
# Name: doc_id, dtype: int64
# doc_id = 6091    6399
# Name: doc_id, dtype: int64
# doc_title = 6091    6399
# Name: doc_id, dtype: int64
# year_of_pub = 6091    6399
# Name: doc_id, dtype: int64
# doc_id = 3475    3654
# Name: doc_id, dtype: int64
# doc_title = 3475    3654
# Name: doc_id, dtype: int64
# year_of_pub = 3475    3654
# Name: doc_id, dtype: int64
# doc_id = 11471    12256
# Name: doc_id, dtype: int64
# doc_title = 11471    12256
# Name: doc_id, dtype: int64
# year_of_pub = 11471    12256
# Name: doc_id, dtype: int64
# doc_id = 19071    20150
# Name: doc_id, dtype: int64
# doc_title = 19071    20150
# Name: doc_id, dtype: int64
# year_of_pub = 19071    20150
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 1557    1635
# Name: doc_id, dtype: int64
# doc_title = 1557    1635
# Name: doc_id, dtype: int64
# year_of_pub = 1557    1635
# Name: doc_id, dtype: int64
# doc_id = 8827    9310
# Name: doc_id, dtype: int64
# doc_title = 8827    9310
# Name: doc_id, dtype: int64
# year_of_pub = 8827    9310
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 9485    10009
# Name: doc_id, dtype: int64
# doc_title = 9485    10009
# Name: doc_id, dtype: int64
# year_of_pub = 9485    10009
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 2303    2419
# Name: doc_id, dtype: int64
# doc_title = 2303    2419
# Name: doc_id, dtype: int64
# year_of_pub = 2303    2419
# Name: doc_id, dtype: int64
# doc_id = 27237    28682
# Name: doc_id, dtype: int64
# doc_title = 27237    28682
# Name: doc_id, dtype: int64
# year_of_pub = 27237    28682
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 21290    22436
# Name: doc_id, dtype: int64
# doc_title = 21290    22436
# Name: doc_id, dtype: int64
# year_of_pub = 21290    22436
# Name: doc_id, dtype: int64
# doc_id = 10022    10614
# Name: doc_id, dtype: int64
# doc_title = 10022    10614
# Name: doc_id, dtype: int64
# year_of_pub = 10022    10614
# Name: doc_id, dtype: int64
# doc_id = 8724    9192
# Name: doc_id, dtype: int64
# doc_title = 8724    9192
# Name: doc_id, dtype: int64
# year_of_pub = 8724    9192
# Name: doc_id, dtype: int64
# doc_id = 26456    27846
# Name: doc_id, dtype: int64
# doc_title = 26456    27846
# Name: doc_id, dtype: int64
# year_of_pub = 26456    27846
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 12614    13426
# Name: doc_id, dtype: int64
# doc_title = 12614    13426
# Name: doc_id, dtype: int64
# year_of_pub = 12614    13426
# Name: doc_id, dtype: int64
# doc_id = 8569    9046
# Name: doc_id, dtype: int64
# doc_title = 8569    9046
# Name: doc_id, dtype: int64
# year_of_pub = 8569    9046
# Name: doc_id, dtype: int64
# doc_id = 21425    22579
# Name: doc_id, dtype: int64
# doc_title = 21425    22579
# Name: doc_id, dtype: int64
# year_of_pub = 21425    22579
# Name: doc_id, dtype: int64
# doc_id = 14344    15245
# Name: doc_id, dtype: int64
# doc_title = 14344    15245
# Name: doc_id, dtype: int64
# year_of_pub = 14344    15245
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16192    17159
# Name: doc_id, dtype: int64
# doc_title = 16192    17159
# Name: doc_id, dtype: int64
# year_of_pub = 16192    17159
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 13638    14505
# Name: doc_id, dtype: int64
# doc_title = 13638    14505
# Name: doc_id, dtype: int64
# year_of_pub = 13638    14505
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 18690    19762
# Name: doc_id, dtype: int64
# doc_title = 18690    19762
# Name: doc_id, dtype: int64
# year_of_pub = 18690    19762
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 23327    24602
# Name: doc_id, dtype: int64
# doc_title = 23327    24602
# Name: doc_id, dtype: int64
# year_of_pub = 23327    24602
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3030    3186
# Name: doc_id, dtype: int64
# doc_title = 3030    3186
# Name: doc_id, dtype: int64
# year_of_pub = 3030    3186
# Name: doc_id, dtype: int64
# doc_id = 18555    19622
# Name: doc_id, dtype: int64
# doc_title = 18555    19622
# Name: doc_id, dtype: int64
# year_of_pub = 18555    19622
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 10008    10598
# Name: doc_id, dtype: int64
# doc_title = 10008    10598
# Name: doc_id, dtype: int64
# year_of_pub = 10008    10598
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3066    3228
# Name: doc_id, dtype: int64
# doc_title = 3066    3228
# Name: doc_id, dtype: int64
# year_of_pub = 3066    3228
# Name: doc_id, dtype: int64
# doc_id = 8564    9041
# Name: doc_id, dtype: int64
# doc_title = 8564    9041
# Name: doc_id, dtype: int64
# year_of_pub = 8564    9041
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16997    17996
# Name: doc_id, dtype: int64
# doc_title = 16997    17996
# Name: doc_id, dtype: int64
# year_of_pub = 16997    17996
# Name: doc_id, dtype: int64
# doc_id = 18916    19981
# 18917    19982
# Name: doc_id, dtype: int64
# doc_title = 18916    19981
# 18917    19982
# Name: doc_id, dtype: int64
# year_of_pub = 18916    19981
# 18917    19982
# Name: doc_id, dtype: int64
# doc_id = 6287      6599
# 21223    22367
# Name: doc_id, dtype: int64
# doc_title = 6287      6599
# 21223    22367
# Name: doc_id, dtype: int64
# year_of_pub = 6287      6599
# 21223    22367
# Name: doc_id, dtype: int64
# doc_id = 470    501
# Name: doc_id, dtype: int64
# doc_title = 470    501
# Name: doc_id, dtype: int64
# year_of_pub = 470    501
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 23278    24544
# Name: doc_id, dtype: int64
# doc_title = 23278    24544
# Name: doc_id, dtype: int64
# year_of_pub = 23278    24544
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 26445    27835
# Name: doc_id, dtype: int64
# doc_title = 26445    27835
# Name: doc_id, dtype: int64
# year_of_pub = 26445    27835
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 8201    8671
# Name: doc_id, dtype: int64
# doc_title = 8201    8671
# Name: doc_id, dtype: int64
# year_of_pub = 8201    8671
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 24312    25624
# Name: doc_id, dtype: int64
# doc_title = 24312    25624
# Name: doc_id, dtype: int64
# year_of_pub = 24312    25624
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 8214    8684
# 8384    8859
# 8926    9415
# Name: doc_id, dtype: int64
# doc_title = 8214    8684
# 8384    8859
# 8926    9415
# Name: doc_id, dtype: int64
# year_of_pub = 8214    8684
# 8384    8859
# 8926    9415
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 8050    8515
# Name: doc_id, dtype: int64
# doc_title = 8050    8515
# Name: doc_id, dtype: int64
# year_of_pub = 8050    8515
# Name: doc_id, dtype: int64
# doc_id = 1521    1599
# Name: doc_id, dtype: int64
# doc_title = 1521    1599
# Name: doc_id, dtype: int64
# year_of_pub = 1521    1599
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 22759    23996
# Name: doc_id, dtype: int64
# doc_title = 22759    23996
# Name: doc_id, dtype: int64
# year_of_pub = 22759    23996
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 452    480
# Name: doc_id, dtype: int64
# doc_title = 452    480
# Name: doc_id, dtype: int64
# year_of_pub = 452    480
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 11680    12472
# Name: doc_id, dtype: int64
# doc_title = 11680    12472
# Name: doc_id, dtype: int64
# year_of_pub = 11680    12472
# Name: doc_id, dtype: int64
# doc_id = 1544    1622
# Name: doc_id, dtype: int64
# doc_title = 1544    1622
# Name: doc_id, dtype: int64
# year_of_pub = 1544    1622
# Name: doc_id, dtype: int64
# doc_id = 4200    4411
# Name: doc_id, dtype: int64
# doc_title = 4200    4411
# Name: doc_id, dtype: int64
# year_of_pub = 4200    4411
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3920    4123
# Name: doc_id, dtype: int64
# doc_title = 3920    4123
# Name: doc_id, dtype: int64
# year_of_pub = 3920    4123
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 26448    27838
# Name: doc_id, dtype: int64
# doc_title = 26448    27838
# Name: doc_id, dtype: int64
# year_of_pub = 26448    27838
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 22162    23363
# Name: doc_id, dtype: int64
# doc_title = 22162    23363
# Name: doc_id, dtype: int64
# year_of_pub = 22162    23363
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 11473    12258
# Name: doc_id, dtype: int64
# doc_title = 11473    12258
# Name: doc_id, dtype: int64
# year_of_pub = 11473    12258
# Name: doc_id, dtype: int64
# doc_id = 18535    19602
# Name: doc_id, dtype: int64
# doc_title = 18535    19602
# Name: doc_id, dtype: int64
# year_of_pub = 18535    19602
# Name: doc_id, dtype: int64
# doc_id = 4197    4408
# Name: doc_id, dtype: int64
# doc_title = 4197    4408
# Name: doc_id, dtype: int64
# year_of_pub = 4197    4408
# Name: doc_id, dtype: int64
# doc_id = 10893    11608
# Name: doc_id, dtype: int64
# doc_title = 10893    11608
# Name: doc_id, dtype: int64
# year_of_pub = 10893    11608
# Name: doc_id, dtype: int64
# doc_id = 18087    19141
# Name: doc_id, dtype: int64
# doc_title = 18087    19141
# Name: doc_id, dtype: int64
# year_of_pub = 18087    19141
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 6848    7273
# Name: doc_id, dtype: int64
# doc_title = 6848    7273
# Name: doc_id, dtype: int64
# year_of_pub = 6848    7273
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 100    111
# Name: doc_id, dtype: int64
# doc_title = 100    111
# Name: doc_id, dtype: int64
# year_of_pub = 100    111
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16191    17158
# Name: doc_id, dtype: int64
# doc_title = 16191    17158
# Name: doc_id, dtype: int64
# year_of_pub = 16191    17158
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 23585    24864
# Name: doc_id, dtype: int64
# doc_title = 23585    24864
# Name: doc_id, dtype: int64
# year_of_pub = 23585    24864
# Name: doc_id, dtype: int64
# doc_id = 15265    16198
# Name: doc_id, dtype: int64
# doc_title = 15265    16198
# Name: doc_id, dtype: int64
# year_of_pub = 15265    16198
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3242    3411
# Name: doc_id, dtype: int64
# doc_title = 3242    3411
# Name: doc_id, dtype: int64
# year_of_pub = 3242    3411
# Name: doc_id, dtype: int64
# doc_id = 17844    18878
# Name: doc_id, dtype: int64
# doc_title = 17844    18878
# Name: doc_id, dtype: int64
# year_of_pub = 17844    18878
# Name: doc_id, dtype: int64
# doc_id = 2499    2628
# Name: doc_id, dtype: int64
# doc_title = 2499    2628
# Name: doc_id, dtype: int64
# year_of_pub = 2499    2628
# Name: doc_id, dtype: int64
# doc_id = 13286    14130
# Name: doc_id, dtype: int64
# doc_title = 13286    14130
# Name: doc_id, dtype: int64
# year_of_pub = 13286    14130
# Name: doc_id, dtype: int64
# doc_id = 24574    25903
# Name: doc_id, dtype: int64
# doc_title = 24574    25903
# Name: doc_id, dtype: int64
# year_of_pub = 24574    25903
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 1875    1971
# Name: doc_id, dtype: int64
# doc_title = 1875    1971
# Name: doc_id, dtype: int64
# year_of_pub = 1875    1971
# Name: doc_id, dtype: int64
# doc_id = 26544    27935
# Name: doc_id, dtype: int64
# doc_title = 26544    27935
# Name: doc_id, dtype: int64
# year_of_pub = 26544    27935
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3051    3212
# Name: doc_id, dtype: int64
# doc_title = 3051    3212
# Name: doc_id, dtype: int64
# year_of_pub = 3051    3212
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3168    3334
# Name: doc_id, dtype: int64
# doc_title = 3168    3334
# Name: doc_id, dtype: int64
# year_of_pub = 3168    3334
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 372    400
# Name: doc_id, dtype: int64
# doc_title = 372    400
# Name: doc_id, dtype: int64
# year_of_pub = 372    400
# Name: doc_id, dtype: int64
# doc_id = 16189    17156
# Name: doc_id, dtype: int64
# doc_title = 16189    17156
# Name: doc_id, dtype: int64
# year_of_pub = 16189    17156
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 15607    16543
# Name: doc_id, dtype: int64
# doc_title = 15607    16543
# Name: doc_id, dtype: int64
# year_of_pub = 15607    16543
# Name: doc_id, dtype: int64
# doc_id = 798    845
# Name: doc_id, dtype: int64
# doc_title = 798    845
# Name: doc_id, dtype: int64
# year_of_pub = 798    845
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 5118    5366
# Name: doc_id, dtype: int64
# doc_title = 5118    5366
# Name: doc_id, dtype: int64
# year_of_pub = 5118    5366
# Name: doc_id, dtype: int64
# doc_id = 7566    8012
# Name: doc_id, dtype: int64
# doc_title = 7566    8012
# Name: doc_id, dtype: int64
# year_of_pub = 7566    8012
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 8560    9037
# Name: doc_id, dtype: int64
# doc_title = 8560    9037
# Name: doc_id, dtype: int64
# year_of_pub = 8560    9037
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 7208    7642
# Name: doc_id, dtype: int64
# doc_title = 7208    7642
# Name: doc_id, dtype: int64
# year_of_pub = 7208    7642
# Name: doc_id, dtype: int64
# doc_id = 5117    5365
# Name: doc_id, dtype: int64
# doc_title = 5117    5365
# Name: doc_id, dtype: int64
# year_of_pub = 5117    5365
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 15279    16212
# Name: doc_id, dtype: int64
# doc_title = 15279    16212
# Name: doc_id, dtype: int64
# year_of_pub = 15279    16212
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 21751    22914
# Name: doc_id, dtype: int64
# doc_title = 21751    22914
# Name: doc_id, dtype: int64
# year_of_pub = 21751    22914
# Name: doc_id, dtype: int64
# doc_id = 3276    3447
# Name: doc_id, dtype: int64
# doc_title = 3276    3447
# Name: doc_id, dtype: int64
# year_of_pub = 3276    3447
# Name: doc_id, dtype: int64
# doc_id = 110    121
# Name: doc_id, dtype: int64
# doc_title = 110    121
# Name: doc_id, dtype: int64
# year_of_pub = 110    121
# Name: doc_id, dtype: int64
# doc_id = 15666    16610
# Name: doc_id, dtype: int64
# doc_title = 15666    16610
# Name: doc_id, dtype: int64
# year_of_pub = 15666    16610
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 26461    27850
# Name: doc_id, dtype: int64
# doc_title = 26461    27850
# Name: doc_id, dtype: int64
# year_of_pub = 26461    27850
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 12607    13418
# Name: doc_id, dtype: int64
# doc_title = 12607    13418
# Name: doc_id, dtype: int64
# year_of_pub = 12607    13418
# Name: doc_id, dtype: int64
# doc_id = 23317    24590
# Name: doc_id, dtype: int64
# doc_title = 23317    24590
# Name: doc_id, dtype: int64
# year_of_pub = 23317    24590
# Name: doc_id, dtype: int64
# doc_id = 16484    17455
# Name: doc_id, dtype: int64
# doc_title = 16484    17455
# Name: doc_id, dtype: int64
# year_of_pub = 16484    17455
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 19464    20552
# Name: doc_id, dtype: int64
# doc_title = 19464    20552
# Name: doc_id, dtype: int64
# year_of_pub = 19464    20552
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 21054    22192
# Name: doc_id, dtype: int64
# doc_title = 21054    22192
# Name: doc_id, dtype: int64
# year_of_pub = 21054    22192
# Name: doc_id, dtype: int64
# doc_id = 558        596
# 1532      1610
# 1535      1613
# 2402      2523
# 3067      3229
# 3611      3801
# 4812      5044
# 5498      5770
# 5617      5898
# 10011    10601
# 10562    11188
# 12062    12863
# 12200    13008
# 12304    13113
# 12856    13676
# 13208    14050
# 15086    16012
# 16768    17760
# 16976    17975
# 18480    19548
# 18909    19974
# 22010    23207
# 22248    23462
# 24218    25527
# 24513    25838
# Name: doc_id, dtype: int64
# doc_title = 558        596
# 1532      1610
# 1535      1613
# 2402      2523
# 3067      3229
# 3611      3801
# 4812      5044
# 5498      5770
# 5617      5898
# 10011    10601
# 10562    11188
# 12062    12863
# 12200    13008
# 12304    13113
# 12856    13676
# 13208    14050
# 15086    16012
# 16768    17760
# 16976    17975
# 18480    19548
# 18909    19974
# 22010    23207
# 22248    23462
# 24218    25527
# 24513    25838
# Name: doc_id, dtype: int64
# year_of_pub = 558        596
# 1532      1610
# 1535      1613
# 2402      2523
# 3067      3229
# 3611      3801
# 4812      5044
# 5498      5770
# 5617      5898
# 10011    10601
# 10562    11188
# 12062    12863
# 12200    13008
# 12304    13113
# 12856    13676
# 13208    14050
# 15086    16012
# 16768    17760
# 16976    17975
# 18480    19548
# 18909    19974
# 22010    23207
# 22248    23462
# 24218    25527
# 24513    25838
# Name: doc_id, dtype: int64
# doc_id = 22150    23348
# Name: doc_id, dtype: int64
# doc_title = 22150    23348
# Name: doc_id, dtype: int64
# year_of_pub = 22150    23348
# Name: doc_id, dtype: int64
# doc_id = 6088    6396
# Name: doc_id, dtype: int64
# doc_title = 6088    6396
# Name: doc_id, dtype: int64
# year_of_pub = 6088    6396
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 12837    13656
# Name: doc_id, dtype: int64
# doc_title = 12837    13656
# Name: doc_id, dtype: int64
# year_of_pub = 12837    13656
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16074    17038
# Name: doc_id, dtype: int64
# doc_title = 16074    17038
# Name: doc_id, dtype: int64
# year_of_pub = 16074    17038
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 27014    28451
# Name: doc_id, dtype: int64
# doc_title = 27014    28451
# Name: doc_id, dtype: int64
# year_of_pub = 27014    28451
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 15261    16194
# Name: doc_id, dtype: int64
# doc_title = 15261    16194
# Name: doc_id, dtype: int64
# year_of_pub = 15261    16194
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3466    3646
# Name: doc_id, dtype: int64
# doc_title = 3466    3646
# Name: doc_id, dtype: int64
# year_of_pub = 3466    3646
# Name: doc_id, dtype: int64
# doc_id = 27431    28886
# Name: doc_id, dtype: int64
# doc_title = 27431    28886
# Name: doc_id, dtype: int64
# year_of_pub = 27431    28886
# Name: doc_id, dtype: int64
# doc_id = 17481    18505
# Name: doc_id, dtype: int64
# doc_title = 17481    18505
# Name: doc_id, dtype: int64
# year_of_pub = 17481    18505
# Name: doc_id, dtype: int64
# doc_id = 23590    24869
# Name: doc_id, dtype: int64
# doc_title = 23590    24869
# Name: doc_id, dtype: int64
# year_of_pub = 23590    24869
# Name: doc_id, dtype: int64
# doc_id = 18637    19706
# Name: doc_id, dtype: int64
# doc_title = 18637    19706
# Name: doc_id, dtype: int64
# year_of_pub = 18637    19706
# Name: doc_id, dtype: int64
# doc_id = 24637    25965
# Name: doc_id, dtype: int64
# doc_title = 24637    25965
# Name: doc_id, dtype: int64
# year_of_pub = 24637    25965
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 4960    5202
# Name: doc_id, dtype: int64
# doc_title = 4960    5202
# Name: doc_id, dtype: int64
# year_of_pub = 4960    5202
# Name: doc_id, dtype: int64
# doc_id = 24844    26182
# Name: doc_id, dtype: int64
# doc_title = 24844    26182
# Name: doc_id, dtype: int64
# year_of_pub = 24844    26182
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 19485    20573
# Name: doc_id, dtype: int64
# doc_title = 19485    20573
# Name: doc_id, dtype: int64
# year_of_pub = 19485    20573
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 7078    7504
# Name: doc_id, dtype: int64
# doc_title = 7078    7504
# Name: doc_id, dtype: int64
# year_of_pub = 7078    7504
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16073    17037
# Name: doc_id, dtype: int64
# doc_title = 16073    17037
# Name: doc_id, dtype: int64
# year_of_pub = 16073    17037
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 23318    24592
# Name: doc_id, dtype: int64
# doc_title = 23318    24592
# Name: doc_id, dtype: int64
# year_of_pub = 23318    24592
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 448    476
# Name: doc_id, dtype: int64
# doc_title = 448    476
# Name: doc_id, dtype: int64
# year_of_pub = 448    476
# Name: doc_id, dtype: int64
# doc_id = 23587    24866
# Name: doc_id, dtype: int64
# doc_title = 23587    24866
# Name: doc_id, dtype: int64
# year_of_pub = 23587    24866
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 454    482
# Name: doc_id, dtype: int64
# doc_title = 454    482
# Name: doc_id, dtype: int64
# year_of_pub = 454    482
# Name: doc_id, dtype: int64
# doc_id = 6288    6600
# Name: doc_id, dtype: int64
# doc_title = 6288    6600
# Name: doc_id, dtype: int64
# year_of_pub = 6288    6600
# Name: doc_id, dtype: int64
# doc_id = 22176    23385
# Name: doc_id, dtype: int64
# doc_title = 22176    23385
# Name: doc_id, dtype: int64
# year_of_pub = 22176    23385
# Name: doc_id, dtype: int64
# doc_id = 27456    28912
# Name: doc_id, dtype: int64
# doc_title = 27456    28912
# Name: doc_id, dtype: int64
# year_of_pub = 27456    28912
# Name: doc_id, dtype: int64
# doc_id = 23602    24881
# Name: doc_id, dtype: int64
# doc_title = 23602    24881
# Name: doc_id, dtype: int64
# year_of_pub = 23602    24881
# Name: doc_id, dtype: int64
# doc_id = 24986    26323
# Name: doc_id, dtype: int64
# doc_title = 24986    26323
# Name: doc_id, dtype: int64
# year_of_pub = 24986    26323
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 15668    16614
# Name: doc_id, dtype: int64
# doc_title = 15668    16614
# Name: doc_id, dtype: int64
# year_of_pub = 15668    16614
# Name: doc_id, dtype: int64
# doc_id = 8718    9185
# Name: doc_id, dtype: int64
# doc_title = 8718    9185
# Name: doc_id, dtype: int64
# year_of_pub = 8718    9185
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 7542    7983
# Name: doc_id, dtype: int64
# doc_title = 7542    7983
# Name: doc_id, dtype: int64
# year_of_pub = 7542    7983
# Name: doc_id, dtype: int64
# doc_id = 2068    2171
# Name: doc_id, dtype: int64
# doc_title = 2068    2171
# Name: doc_id, dtype: int64
# year_of_pub = 2068    2171
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 1932    2030
# Name: doc_id, dtype: int64
# doc_title = 1932    2030
# Name: doc_id, dtype: int64
# year_of_pub = 1932    2030
# Name: doc_id, dtype: int64
# doc_id = 1555    1633
# Name: doc_id, dtype: int64
# doc_title = 1555    1633
# Name: doc_id, dtype: int64
# year_of_pub = 1555    1633
# Name: doc_id, dtype: int64
# doc_id = 16754    17744
# Name: doc_id, dtype: int64
# doc_title = 16754    17744
# Name: doc_id, dtype: int64
# year_of_pub = 16754    17744
# Name: doc_id, dtype: int64
# doc_id = 6078    6385
# Name: doc_id, dtype: int64
# doc_title = 6078    6385
# Name: doc_id, dtype: int64
# year_of_pub = 6078    6385
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 24010    25300
# Name: doc_id, dtype: int64
# doc_title = 24010    25300
# Name: doc_id, dtype: int64
# year_of_pub = 24010    25300
# Name: doc_id, dtype: int64
# doc_id = 17215    18231
# Name: doc_id, dtype: int64
# doc_title = 17215    18231
# Name: doc_id, dtype: int64
# year_of_pub = 17215    18231
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16067    17031
# Name: doc_id, dtype: int64
# doc_title = 16067    17031
# Name: doc_id, dtype: int64
# year_of_pub = 16067    17031
# Name: doc_id, dtype: int64
# doc_id = 8733    9201
# Name: doc_id, dtype: int64
# doc_title = 8733    9201
# Name: doc_id, dtype: int64
# year_of_pub = 8733    9201
# Name: doc_id, dtype: int64
# doc_id = 8198    8668
# Name: doc_id, dtype: int64
# doc_title = 8198    8668
# Name: doc_id, dtype: int64
# year_of_pub = 8198    8668
# Name: doc_id, dtype: int64
# doc_id = 27418    28872
# Name: doc_id, dtype: int64
# doc_title = 27418    28872
# Name: doc_id, dtype: int64
# year_of_pub = 27418    28872
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 453    481
# Name: doc_id, dtype: int64
# doc_title = 453    481
# Name: doc_id, dtype: int64
# year_of_pub = 453    481
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 3039    3195
# Name: doc_id, dtype: int64
# doc_title = 3039    3195
# Name: doc_id, dtype: int64
# year_of_pub = 3039    3195
# Name: doc_id, dtype: int64
# doc_id = 10784    11440
# Name: doc_id, dtype: int64
# doc_title = 10784    11440
# Name: doc_id, dtype: int64
# year_of_pub = 10784    11440
# Name: doc_id, dtype: int64
# doc_id = 16487    17460
# Name: doc_id, dtype: int64
# doc_title = 16487    17460
# Name: doc_id, dtype: int64
# year_of_pub = 16487    17460
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16180    17147
# Name: doc_id, dtype: int64
# doc_title = 16180    17147
# Name: doc_id, dtype: int64
# year_of_pub = 16180    17147
# Name: doc_id, dtype: int64
# doc_id = 19465    20553
# Name: doc_id, dtype: int64
# doc_title = 19465    20553
# Name: doc_id, dtype: int64
# year_of_pub = 19465    20553
# Name: doc_id, dtype: int64
# doc_id = 8228    8698
# Name: doc_id, dtype: int64
# doc_title = 8228    8698
# Name: doc_id, dtype: int64
# year_of_pub = 8228    8698
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 11924    12717
# Name: doc_id, dtype: int64
# doc_title = 11924    12717
# Name: doc_id, dtype: int64
# year_of_pub = 11924    12717
# Name: doc_id, dtype: int64
# doc_id = 22175    23383
# Name: doc_id, dtype: int64
# doc_title = 22175    23383
# Name: doc_id, dtype: int64
# year_of_pub = 22175    23383
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 14747    15659
# Name: doc_id, dtype: int64
# doc_title = 14747    15659
# Name: doc_id, dtype: int64
# year_of_pub = 14747    15659
# Name: doc_id, dtype: int64
# doc_id = 16211    17178
# Name: doc_id, dtype: int64
# doc_title = 16211    17178
# Name: doc_id, dtype: int64
# year_of_pub = 16211    17178
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 13285    14128
# Name: doc_id, dtype: int64
# doc_title = 13285    14128
# Name: doc_id, dtype: int64
# year_of_pub = 13285    14128
# Name: doc_id, dtype: int64
# doc_id = 18095    19149
# Name: doc_id, dtype: int64
# doc_title = 18095    19149
# Name: doc_id, dtype: int64
# year_of_pub = 18095    19149
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 7894    8357
# Name: doc_id, dtype: int64
# doc_title = 7894    8357
# Name: doc_id, dtype: int64
# year_of_pub = 7894    8357
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 15653    16594
# Name: doc_id, dtype: int64
# doc_title = 15653    16594
# Name: doc_id, dtype: int64
# year_of_pub = 15653    16594
# Name: doc_id, dtype: int64
# doc_id = 328    350
# Name: doc_id, dtype: int64
# doc_title = 328    350
# Name: doc_id, dtype: int64
# year_of_pub = 328    350
# Name: doc_id, dtype: int64
# doc_id = 18092    19146
# Name: doc_id, dtype: int64
# doc_title = 18092    19146
# Name: doc_id, dtype: int64
# year_of_pub = 18092    19146
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 21764    22932
# Name: doc_id, dtype: int64
# doc_title = 21764    22932
# Name: doc_id, dtype: int64
# year_of_pub = 21764    22932
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 10029    10621
# Name: doc_id, dtype: int64
# doc_title = 10029    10621
# Name: doc_id, dtype: int64
# year_of_pub = 10029    10621
# Name: doc_id, dtype: int64
# doc_id = 21755    22919
# Name: doc_id, dtype: int64
# doc_title = 21755    22919
# Name: doc_id, dtype: int64
# year_of_pub = 21755    22919
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 14768    15681
# Name: doc_id, dtype: int64
# doc_title = 14768    15681
# Name: doc_id, dtype: int64
# year_of_pub = 14768    15681
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# ...
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 2761    2907
# Name: doc_id, dtype: int64
# doc_title = 2761    2907
# Name: doc_id, dtype: int64
# year_of_pub = 2761    2907
# Name: doc_id, dtype: int64
# doc_id = 24007    25297
# Name: doc_id, dtype: int64
# doc_title = 24007    25297
# Name: doc_id, dtype: int64
# year_of_pub = 24007    25297
# Name: doc_id, dtype: int64
# doc_id = 27241    28688
# Name: doc_id, dtype: int64
# doc_title = 27241    28688
# Name: doc_id, dtype: int64
# year_of_pub = 27241    28688
# Name: doc_id, dtype: int64
# doc_id = 8226    8696
# Name: doc_id, dtype: int64
# doc_title = 8226    8696
# Name: doc_id, dtype: int64
# year_of_pub = 8226    8696
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 17218    18235
# Name: doc_id, dtype: int64
# doc_title = 17218    18235
# Name: doc_id, dtype: int64
# year_of_pub = 17218    18235
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 22750    23983
# Name: doc_id, dtype: int64
# doc_title = 22750    23983
# Name: doc_id, dtype: int64
# year_of_pub = 22750    23983
# Name: doc_id, dtype: int64
# doc_id = 24548    25876
# Name: doc_id, dtype: int64
# doc_title = 24548    25876
# Name: doc_id, dtype: int64
# year_of_pub = 24548    25876
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 26342    27728
# Name: doc_id, dtype: int64
# doc_title = 26342    27728
# Name: doc_id, dtype: int64
# year_of_pub = 26342    27728
# Name: doc_id, dtype: int64
# doc_id = 23594    24873
# Name: doc_id, dtype: int64
# doc_title = 23594    24873
# Name: doc_id, dtype: int64
# year_of_pub = 23594    24873
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 24650    25978
# Name: doc_id, dtype: int64
# doc_title = 24650    25978
# Name: doc_id, dtype: int64
# year_of_pub = 24650    25978
# Name: doc_id, dtype: int64
# doc_id = 21768    22939
# Name: doc_id, dtype: int64
# doc_title = 21768    22939
# Name: doc_id, dtype: int64
# year_of_pub = 21768    22939
# Name: doc_id, dtype: int64
# doc_id = 354    380
# Name: doc_id, dtype: int64
# doc_title = 354    380
# Name: doc_id, dtype: int64
# year_of_pub = 354    380
# Name: doc_id, dtype: int64
# doc_id = 27405    28859
# Name: doc_id, dtype: int64
# doc_title = 27405    28859
# Name: doc_id, dtype: int64
# year_of_pub = 27405    28859
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 11678    12470
# Name: doc_id, dtype: int64
# doc_title = 11678    12470
# Name: doc_id, dtype: int64
# year_of_pub = 11678    12470
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 9801    10392
# Name: doc_id, dtype: int64
# doc_title = 9801    10392
# Name: doc_id, dtype: int64
# year_of_pub = 9801    10392
# Name: doc_id, dtype: int64
# doc_id = 19467    20555
# Name: doc_id, dtype: int64
# doc_title = 19467    20555
# Name: doc_id, dtype: int64
# year_of_pub = 19467    20555
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 7085    7513
# Name: doc_id, dtype: int64
# doc_title = 7085    7513
# Name: doc_id, dtype: int64
# year_of_pub = 7085    7513
# Name: doc_id, dtype: int64
# doc_id = 8376    8850
# Name: doc_id, dtype: int64
# doc_title = 8376    8850
# Name: doc_id, dtype: int64
# year_of_pub = 8376    8850
# Name: doc_id, dtype: int64
# doc_id = 26340    27726
# Name: doc_id, dtype: int64
# doc_title = 26340    27726
# Name: doc_id, dtype: int64
# year_of_pub = 26340    27726
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 21761    22928
# Name: doc_id, dtype: int64
# doc_title = 21761    22928
# Name: doc_id, dtype: int64
# year_of_pub = 21761    22928
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 17852    18890
# Name: doc_id, dtype: int64
# doc_title = 17852    18890
# Name: doc_id, dtype: int64
# year_of_pub = 17852    18890
# Name: doc_id, dtype: int64
# doc_id = 5282    5551
# Name: doc_id, dtype: int64
# doc_title = 5282    5551
# Name: doc_id, dtype: int64
# year_of_pub = 5282    5551
# Name: doc_id, dtype: int64
# doc_id = 3469    3649
# Name: doc_id, dtype: int64
# doc_title = 3469    3649
# Name: doc_id, dtype: int64
# year_of_pub = 3469    3649
# Name: doc_id, dtype: int64
# doc_id = 16214    17181
# Name: doc_id, dtype: int64
# doc_title = 16214    17181
# Name: doc_id, dtype: int64
# year_of_pub = 16214    17181
# Name: doc_id, dtype: int64
# doc_id = 445    473
# Name: doc_id, dtype: int64
# doc_title = 445    473
# Name: doc_id, dtype: int64
# year_of_pub = 445    473
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 22767    24006
# Name: doc_id, dtype: int64
# doc_title = 22767    24006
# Name: doc_id, dtype: int64
# year_of_pub = 22767    24006
# Name: doc_id, dtype: int64
# doc_id = 7080    7506
# Name: doc_id, dtype: int64
# doc_title = 7080    7506
# Name: doc_id, dtype: int64
# year_of_pub = 7080    7506
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 1716    1795
# Name: doc_id, dtype: int64
# doc_title = 1716    1795
# Name: doc_id, dtype: int64
# year_of_pub = 1716    1795
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 24994    26332
# Name: doc_id, dtype: int64
# doc_title = 24994    26332
# Name: doc_id, dtype: int64
# year_of_pub = 24994    26332
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 16181    17148
# Name: doc_id, dtype: int64
# doc_title = 16181    17148
# Name: doc_id, dtype: int64
# year_of_pub = 16181    17148
# Name: doc_id, dtype: int64
# doc_id = 17850    18885
# Name: doc_id, dtype: int64
# doc_title = 17850    18885
# Name: doc_id, dtype: int64
# year_of_pub = 17850    18885
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 1541    1619
# Name: doc_id, dtype: int64
# doc_title = 1541    1619
# Name: doc_id, dtype: int64
# year_of_pub = 1541    1619
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 18205    19260
# Name: doc_id, dtype: int64
# doc_title = 18205    19260
# Name: doc_id, dtype: int64
# year_of_pub = 18205    19260
# Name: doc_id, dtype: int64
# doc_id = 7557    8003
# Name: doc_id, dtype: int64
# doc_title = 7557    8003
# Name: doc_id, dtype: int64
# year_of_pub = 7557    8003
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 21271    22417
# Name: doc_id, dtype: int64
# doc_title = 21271    22417
# Name: doc_id, dtype: int64
# year_of_pub = 21271    22417
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 7919    8383
# Name: doc_id, dtype: int64
# doc_title = 7919    8383
# Name: doc_id, dtype: int64
# year_of_pub = 7919    8383
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 2076      2180
# 23328    24603
# Name: doc_id, dtype: int64
# doc_title = 2076      2180
# 23328    24603
# Name: doc_id, dtype: int64
# year_of_pub = 2076      2180
# 23328    24603
# Name: doc_id, dtype: int64
# doc_id = 23164    24418
# Name: doc_id, dtype: int64
# doc_title = 23164    24418
# Name: doc_id, dtype: int64
# year_of_pub = 23164    24418
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 18093    19147
# Name: doc_id, dtype: int64
# doc_title = 18093    19147
# Name: doc_id, dtype: int64
# year_of_pub = 18093    19147
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 461    490
# Name: doc_id, dtype: int64
# doc_title = 461    490
# Name: doc_id, dtype: int64
# year_of_pub = 461    490
# Name: doc_id, dtype: int64
# doc_id = 558        596
# 1532      1610
# 1535      1613
# 2402      2523
# 3067      3229
# 3611      3801
# 4812      5044
# 5498      5770
# 5617      5898
# 10011    10601
# 10562    11188
# 12062    12863
# 12200    13008
# 12304    13113
# 12856    13676
# 13208    14050
# 15086    16012
# 16768    17760
# 16976    17975
# 18480    19548
# 18909    19974
# 22010    23207
# 22248    23462
# 24218    25527
# 24513    25838
# Name: doc_id, dtype: int64
# doc_title = 558        596
# 1532      1610
# 1535      1613
# 2402      2523
# 3067      3229
# 3611      3801
# 4812      5044
# 5498      5770
# 5617      5898
# 10011    10601
# 10562    11188
# 12062    12863
# 12200    13008
# 12304    13113
# 12856    13676
# 13208    14050
# 15086    16012
# 16768    17760
# 16976    17975
# 18480    19548
# 18909    19974
# 22010    23207
# 22248    23462
# 24218    25527
# 24513    25838
# Name: doc_id, dtype: int64
# year_of_pub = 558        596
# 1532      1610
# 1535      1613
# 2402      2523
# 3067      3229
# 3611      3801
# 4812      5044
# 5498      5770
# 5617      5898
# 10011    10601
# 10562    11188
# 12062    12863
# 12200    13008
# 12304    13113
# 12856    13676
# 13208    14050
# 15086    16012
# 16768    17760
# 16976    17975
# 18480    19548
# 18909    19974
# 22010    23207
# 22248    23462
# 24218    25527
# 24513    25838
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 10567    11193
# Name: doc_id, dtype: int64
# doc_title = 10567    11193
# Name: doc_id, dtype: int64
# year_of_pub = 10567    11193
# Name: doc_id, dtype: int64
# doc_id = 23311    24584
# Name: doc_id, dtype: int64
# doc_title = 23311    24584
# Name: doc_id, dtype: int64
# year_of_pub = 23311    24584
# Name: doc_id, dtype: int64
# doc_id = 15290    16223
# Name: doc_id, dtype: int64
# doc_title = 15290    16223
# Name: doc_id, dtype: int64
# year_of_pub = 15290    16223
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 4502    4714
# Name: doc_id, dtype: int64
# doc_title = 4502    4714
# Name: doc_id, dtype: int64
# year_of_pub = 4502    4714
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 23302    24575
# Name: doc_id, dtype: int64
# doc_title = 23302    24575
# Name: doc_id, dtype: int64
# year_of_pub = 23302    24575
# Name: doc_id, dtype: int64
# doc_id = 27428    28883
# Name: doc_id, dtype: int64
# doc_title = 27428    28883
# Name: doc_id, dtype: int64
# year_of_pub = 27428    28883
# Name: doc_id, dtype: int64
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = Series([], Name: doc_id, dtype: int64)
# doc_title = Series([], Name: doc_id, dtype: int64)
# year_of_pub = Series([], Name: doc_id, dtype: int64)
# doc_id = 10025    10617
# Name: doc_id, dtype: int64
# doc_title = 10025    10617
# Name: doc_id, dtype: int64
# year_of_pub = 10025    10617
# Name: doc_id, dtype: int64
