# %%
author_list = [2,121,111] 
doc_id = 2178

# %%
import StyloNeural as Stylo

# %%
(predYList, predY) = Stylo.getResults(authorList=author_list,doc_id=2178)
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 950 (CNMeM is disabled, cuDNN 5005)
# Found 400000 word vectors.
# [nltk_data] Downloading package punkt to /home/common/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Execution completed
# Read completed
# Number of rows: 55
# author_id       int64
# doc_content    object
# dtype: object
# Data Frame created: Shape: (5707, 2)
# Found 5707 texts.
# Found 64434 unique tokens.
# Shape of data tensor: (5707, 1000)
# Shape of label tensor: (5707, 3)
# Train on 4566 samples, validate on 1141 samples
# Epoch 1/30
# 4566/4566 [==============================] - 27s - loss: 0.7560 - acc: 0.6789 - val_loss: 1.2007 - val_acc: 0.5302
# Epoch 2/30
# 4566/4566 [==============================] - 27s - loss: 0.7016 - acc: 0.6921 - val_loss: 1.0974 - val_acc: 0.5302
# Epoch 3/30
# 4566/4566 [==============================] - 27s - loss: 0.7190 - acc: 0.6923 - val_loss: 1.0938 - val_acc: 0.5302
# Epoch 4/30
# ...

# %%
print predY
# Out:
# [ 0.79757106  0.06320742  0.13922143]

# %%
print predYList
# Out:
# [[  2.43287131e-01   8.68919492e-02   6.69820964e-01]
#  [  5.68916976e-01   1.15999326e-01   3.15083712e-01]
#  [  5.71161747e-01   1.17814474e-01   3.11023802e-01]
#  [  2.72797197e-01   7.07156882e-02   6.56487048e-01]
#  [  1.72209829e-01   4.77432832e-02   7.80046880e-01]
#  [  6.09413862e-01   9.49458629e-02   2.95640260e-01]
#  [  4.74632204e-01   1.14773169e-01   4.10594672e-01]
#  [  9.89367068e-01   1.03434557e-02   2.89477932e-04]
#  [  9.20066118e-01   4.50222157e-02   3.49117145e-02]
#  [  9.65069711e-01   2.71223895e-02   7.80794024e-03]
#  [  7.20185399e-01   1.40753567e-01   1.39061034e-01]
#  [  5.32381237e-01   8.34693387e-02   3.84149402e-01]
#  [  8.97315025e-01   5.10958321e-02   5.15891127e-02]
#  [  7.09040403e-01   9.95055437e-02   1.91454098e-01]
#  [  9.02898133e-01   5.75646386e-02   3.95372212e-02]
#  [  9.46419775e-01   3.19055319e-02   2.16746554e-02]
#  [  4.91138548e-01   1.06273405e-01   4.02587980e-01]
# ...
